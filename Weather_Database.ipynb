# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
# Import the API key.

from config import weather_api_key
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low = -90,high = 90,size=2000)
lngs = np.random.uniform(low = -180,high =180,size=2000)
lat_lngs = zip(lats,lngs)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates =  list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)
# Print the city count to confirm sufficient count
        
print(f"Number of cities generated: {len(cities)}")

        
# Print the city count to confirm sufficient count.
print(f"Number of cities generated: {len(cities)}")
# Out:
# Number of cities generated: 746
# Number of cities generated: 746

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
     # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
       
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | airai
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | itarema
# Processing Record 6 of Set 1 | andarab
# City not found. Skipping...
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | marshfield
# Processing Record 10 of Set 1 | marawi
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | banjar
# Processing Record 15 of Set 1 | ayolas
# Processing Record 16 of Set 1 | mecca
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | tambacounda
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | san jeronimo
# Processing Record 23 of Set 1 | vestbygda
# City not found. Skipping...
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | kisangani
# Processing Record 26 of Set 1 | acapulco
# Processing Record 27 of Set 1 | constitucion
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | rafraf
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | magadan
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | pochutla
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | veraval
# Processing Record 38 of Set 1 | riyadh
# Processing Record 39 of Set 1 | huambo
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | lorengau
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | ust-ishim
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | keti bandar
# Processing Record 48 of Set 1 | kirakira
# Processing Record 49 of Set 1 | wajir
# Processing Record 50 of Set 1 | sal rei
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | antofagasta
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | murdochville
# Processing Record 5 of Set 2 | ternate
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | santa ines
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | oranjemund
# Processing Record 10 of Set 2 | vostok
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | lasa
# Processing Record 13 of Set 2 | uberlandia
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | warah
# Processing Record 21 of Set 2 | marystown
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | cap-aux-meules
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | ocean city
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | norman wells
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | bambous virieux
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | suntar
# Processing Record 39 of Set 2 | sakakah
# Processing Record 40 of Set 2 | xique-xique
# Processing Record 41 of Set 2 | bolshaya rechka
# Processing Record 42 of Set 2 | kumano
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | chiang kham
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | purpe
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | tarbagatay
# Processing Record 50 of Set 2 | antalaha
# Processing Record 1 of Set 3 | vao
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | neryungri
# Processing Record 4 of Set 3 | valavanur
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | vardo
# Processing Record 9 of Set 3 | honiara
# Processing Record 10 of Set 3 | porto novo
# Processing Record 11 of Set 3 | bud
# Processing Record 12 of Set 3 | soe
# Processing Record 13 of Set 3 | skelleftea
# Processing Record 14 of Set 3 | teknaf
# Processing Record 15 of Set 3 | cayenne
# Processing Record 16 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 3 | trier
# Processing Record 18 of Set 3 | hindoria
# Processing Record 19 of Set 3 | maulvi bazar
# City not found. Skipping...
# Processing Record 20 of Set 3 | jiexiu
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 3 | wasilla
# Processing Record 24 of Set 3 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | tiznit
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | alekseyevsk
# Processing Record 29 of Set 3 | waingapu
# Processing Record 30 of Set 3 | paita
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 33 of Set 3 | adrar
# Processing Record 34 of Set 3 | laurel
# Processing Record 35 of Set 3 | fjerritslev
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | saint-pierre
# Processing Record 38 of Set 3 | thermon
# City not found. Skipping...
# Processing Record 39 of Set 3 | praia da vitoria
# Processing Record 40 of Set 3 | port blair
# Processing Record 41 of Set 3 | te anau
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | houma
# Processing Record 44 of Set 3 | touros
# Processing Record 45 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 3 | okhotsk
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | albanel
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | champerico
# Processing Record 1 of Set 4 | farafangana
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | san carlos
# Processing Record 4 of Set 4 | candelaria
# Processing Record 5 of Set 4 | atuona
# Processing Record 6 of Set 4 | tall kayf
# Processing Record 7 of Set 4 | ajdabiya
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | sabha
# Processing Record 12 of Set 4 | palana
# Processing Record 13 of Set 4 | farah
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | eldersburg
# Processing Record 16 of Set 4 | axim
# Processing Record 17 of Set 4 | roald
# Processing Record 18 of Set 4 | krasnoselkup
# Processing Record 19 of Set 4 | lyngseidet
# Processing Record 20 of Set 4 | grand gaube
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | hermanus
# Processing Record 23 of Set 4 | egvekinot
# Processing Record 24 of Set 4 | eyl
# Processing Record 25 of Set 4 | turukhansk
# Processing Record 26 of Set 4 | nizhniy kuranakh
# Processing Record 27 of Set 4 | yuncheng
# Processing Record 28 of Set 4 | bathsheba
# Processing Record 29 of Set 4 | takoradi
# Processing Record 30 of Set 4 | kenai
# Processing Record 31 of Set 4 | komsomolskiy
# Processing Record 32 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | bayangol
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | moree
# Processing Record 37 of Set 4 | maicao
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | broken hill
# Processing Record 43 of Set 4 | acarau
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | maralal
# Processing Record 46 of Set 4 | tabou
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | the hammocks
# Processing Record 49 of Set 4 | bubaque
# Processing Record 50 of Set 4 | lappeenranta
# Processing Record 1 of Set 5 | alofi
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | kruisfontein
# Processing Record 4 of Set 5 | riachao do jacuipe
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | hobart
# Processing Record 7 of Set 5 | rio grande
# Processing Record 8 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 5 | trebisov
# Processing Record 10 of Set 5 | ludvika
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | clarence town
# Processing Record 13 of Set 5 | betare oya
# Processing Record 14 of Set 5 | aberdeen
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | jashpurnagar
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | akdepe
# Processing Record 19 of Set 5 | fukue
# Processing Record 20 of Set 5 | ancud
# Processing Record 21 of Set 5 | daru
# Processing Record 22 of Set 5 | pucallpa
# Processing Record 23 of Set 5 | meridian
# Processing Record 24 of Set 5 | yar-sale
# Processing Record 25 of Set 5 | maridi
# Processing Record 26 of Set 5 | semirom
# Processing Record 27 of Set 5 | valparaiso
# Processing Record 28 of Set 5 | tanjong sepat
# City not found. Skipping...
# Processing Record 29 of Set 5 | sioux lookout
# Processing Record 30 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 5 | moengo
# Processing Record 32 of Set 5 | byron bay
# Processing Record 33 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 5 | jumla
# Processing Record 35 of Set 5 | burnie
# Processing Record 36 of Set 5 | vaini
# Processing Record 37 of Set 5 | mattru
# Processing Record 38 of Set 5 | am timan
# Processing Record 39 of Set 5 | kodiak
# Processing Record 40 of Set 5 | torbay
# Processing Record 41 of Set 5 | makhu
# Processing Record 42 of Set 5 | patitirion
# Processing Record 43 of Set 5 | ornskoldsvik
# Processing Record 44 of Set 5 | zyryanka
# Processing Record 45 of Set 5 | tutoia
# Processing Record 46 of Set 5 | teya
# Processing Record 47 of Set 5 | marion
# Processing Record 48 of Set 5 | lahijan
# Processing Record 49 of Set 5 | caravelas
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | gilgit
# Processing Record 2 of Set 6 | nioro
# Processing Record 3 of Set 6 | afyonkarahisar
# Processing Record 4 of Set 6 | yagodnoye
# Processing Record 5 of Set 6 | lamu
# Processing Record 6 of Set 6 | olga
# Processing Record 7 of Set 6 | dinguiraye
# Processing Record 8 of Set 6 | skibbereen
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | fredericton
# Processing Record 11 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 6 | hovd
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | asfi
# Processing Record 15 of Set 6 | mataram
# Processing Record 16 of Set 6 | iaciara
# Processing Record 17 of Set 6 | baherden
# Processing Record 18 of Set 6 | nusaybin
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | oksfjord
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | santa rosa
# Processing Record 23 of Set 6 | redding
# Processing Record 24 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 6 | mana
# Processing Record 26 of Set 6 | waipawa
# Processing Record 27 of Set 6 | ahipara
# Processing Record 28 of Set 6 | ugoofaaru
# Processing Record 29 of Set 6 | harnoli
# Processing Record 30 of Set 6 | rocha
# Processing Record 31 of Set 6 | christchurch
# Processing Record 32 of Set 6 | kaeo
# Processing Record 33 of Set 6 | miranda
# Processing Record 34 of Set 6 | juazeiro
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | rawson
# Processing Record 37 of Set 6 | nerchinskiy zavod
# Processing Record 38 of Set 6 | asau
# Processing Record 39 of Set 6 | iskateley
# Processing Record 40 of Set 6 | tuatapere
# Processing Record 41 of Set 6 | sosnovo-ozerskoye
# Processing Record 42 of Set 6 | orlik
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | punto fijo
# Processing Record 45 of Set 6 | new glasgow
# Processing Record 46 of Set 6 | san quintin
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | storforshei
# Processing Record 49 of Set 6 | acari
# Processing Record 50 of Set 6 | northam
# Processing Record 1 of Set 7 | morgan city
# Processing Record 2 of Set 7 | huarmey
# Processing Record 3 of Set 7 | mastung
# Processing Record 4 of Set 7 | camana
# Processing Record 5 of Set 7 | mabiton
# Processing Record 6 of Set 7 | point pedro
# Processing Record 7 of Set 7 | lata
# Processing Record 8 of Set 7 | racine
# Processing Record 9 of Set 7 | dana point
# Processing Record 10 of Set 7 | jiblah
# Processing Record 11 of Set 7 | reconquista
# Processing Record 12 of Set 7 | terrace
# Processing Record 13 of Set 7 | omboue
# Processing Record 14 of Set 7 | saldanha
# Processing Record 15 of Set 7 | marsh harbour
# Processing Record 16 of Set 7 | praia
# Processing Record 17 of Set 7 | nikolskoye
# Processing Record 18 of Set 7 | sao geraldo do araguaia
# Processing Record 19 of Set 7 | songjianghe
# Processing Record 20 of Set 7 | dharchula
# Processing Record 21 of Set 7 | lohja
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | lebu
# Processing Record 24 of Set 7 | homer
# Processing Record 25 of Set 7 | west plains
# Processing Record 26 of Set 7 | caohai
# Processing Record 27 of Set 7 | licheng
# Processing Record 28 of Set 7 | diamantino
# Processing Record 29 of Set 7 | atasu
# Processing Record 30 of Set 7 | nishihara
# Processing Record 31 of Set 7 | araouane
# Processing Record 32 of Set 7 | kargasok
# Processing Record 33 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 34 of Set 7 | san juan
# Processing Record 35 of Set 7 | upata
# Processing Record 36 of Set 7 | pierre
# Processing Record 37 of Set 7 | benjamin hill
# Processing Record 38 of Set 7 | bad reichenhall
# Processing Record 39 of Set 7 | belousovka
# Processing Record 40 of Set 7 | carauari
# Processing Record 41 of Set 7 | alekseyevka
# Processing Record 42 of Set 7 | adrian
# Processing Record 43 of Set 7 | haines junction
# Processing Record 44 of Set 7 | buchanan
# Processing Record 45 of Set 7 | babstovo
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | zhuanghe
# Processing Record 48 of Set 7 | puerto del rosario
# Processing Record 49 of Set 7 | rancho palos verdes
# Processing Record 50 of Set 7 | dongying
# Processing Record 1 of Set 8 | salinopolis
# Processing Record 2 of Set 8 | itoman
# Processing Record 3 of Set 8 | alexandria
# Processing Record 4 of Set 8 | panaba
# Processing Record 5 of Set 8 | mayo
# Processing Record 6 of Set 8 | ust-nera
# Processing Record 7 of Set 8 | mugur-aksy
# Processing Record 8 of Set 8 | sao joao da barra
# Processing Record 9 of Set 8 | wiang sa
# Processing Record 10 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 8 | moose factory
# Processing Record 12 of Set 8 | shingu
# Processing Record 13 of Set 8 | nanortalik
# Processing Record 14 of Set 8 | abonnema
# Processing Record 15 of Set 8 | santa maria del oro
# Processing Record 16 of Set 8 | zalantun
# Processing Record 17 of Set 8 | malakal
# Processing Record 18 of Set 8 | glendive
# Processing Record 19 of Set 8 | kavaratti
# Processing Record 20 of Set 8 | osa
# Processing Record 21 of Set 8 | lokomotivnyy
# Processing Record 22 of Set 8 | samarai
# Processing Record 23 of Set 8 | lahat
# Processing Record 24 of Set 8 | viransehir
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | kaka
# Processing Record 27 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 8 | hasaki
# Processing Record 29 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 8 | pomabamba
# Processing Record 31 of Set 8 | paducah
# Processing Record 32 of Set 8 | namwala
# Processing Record 33 of Set 8 | yulara
# Processing Record 34 of Set 8 | meget
# Processing Record 35 of Set 8 | kununurra
# Processing Record 36 of Set 8 | bonthe
# Processing Record 37 of Set 8 | biak
# Processing Record 38 of Set 8 | la crosse
# Processing Record 39 of Set 8 | seminole
# Processing Record 40 of Set 8 | khanpur
# Processing Record 41 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 8 | hamilton
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | korla
# Processing Record 46 of Set 8 | sinnamary
# Processing Record 47 of Set 8 | sulangan
# Processing Record 48 of Set 8 | kearney
# Processing Record 49 of Set 8 | qasigiannguit
# Processing Record 50 of Set 8 | pisco
# Processing Record 1 of Set 9 | wuwei
# Processing Record 2 of Set 9 | nyrob
# Processing Record 3 of Set 9 | chuguyevka
# Processing Record 4 of Set 9 | jardim
# Processing Record 5 of Set 9 | quchan
# Processing Record 6 of Set 9 | tazovskiy
# Processing Record 7 of Set 9 | azovo
# Processing Record 8 of Set 9 | koupela
# Processing Record 9 of Set 9 | brae
# Processing Record 10 of Set 9 | buckeye
# Processing Record 11 of Set 9 | nizhniy tsasuchey
# Processing Record 12 of Set 9 | itacare
# Processing Record 13 of Set 9 | minbu
# Processing Record 14 of Set 9 | indramayu
# Processing Record 15 of Set 9 | milkovo
# Processing Record 16 of Set 9 | rio gallegos
# Processing Record 17 of Set 9 | teguise
# Processing Record 18 of Set 9 | salalah
# Processing Record 19 of Set 9 | katangli
# Processing Record 20 of Set 9 | rusape
# Processing Record 21 of Set 9 | kamaishi
# Processing Record 22 of Set 9 | nynashamn
# Processing Record 23 of Set 9 | khandyga
# Processing Record 24 of Set 9 | havelock
# Processing Record 25 of Set 9 | blagoyevo
# Processing Record 26 of Set 9 | tarko-sale
# Processing Record 27 of Set 9 | beinamar
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | hualmay
# Processing Record 30 of Set 9 | portland
# Processing Record 31 of Set 9 | kano
# Processing Record 32 of Set 9 | askiz
# Processing Record 33 of Set 9 | boende
# Processing Record 34 of Set 9 | cannes
# Processing Record 35 of Set 9 | sao felix do xingu
# Processing Record 36 of Set 9 | erenhot
# Processing Record 37 of Set 9 | iqaluit
# Processing Record 38 of Set 9 | whitianga
# Processing Record 39 of Set 9 | nisko
# Processing Record 40 of Set 9 | katobu
# Processing Record 41 of Set 9 | waddan
# Processing Record 42 of Set 9 | lagoa
# Processing Record 43 of Set 9 | ati
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 9 | pontianak
# Processing Record 47 of Set 9 | zhuhai
# Processing Record 48 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 9 | waitati
# Processing Record 50 of Set 9 | caborca
# Processing Record 1 of Set 10 | gat
# Processing Record 2 of Set 10 | hambantota
# Processing Record 3 of Set 10 | pacific grove
# Processing Record 4 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 5 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 6 of Set 10 | uk
# City not found. Skipping...
# Processing Record 7 of Set 10 | lima
# Processing Record 8 of Set 10 | bryan
# Processing Record 9 of Set 10 | bima
# Processing Record 10 of Set 10 | trapani
# Processing Record 11 of Set 10 | vila do maio
# Processing Record 12 of Set 10 | tongliao
# Processing Record 13 of Set 10 | south sioux city
# Processing Record 14 of Set 10 | shevchenkove
# Processing Record 15 of Set 10 | miri
# Processing Record 16 of Set 10 | syosset
# Processing Record 17 of Set 10 | la ronge
# Processing Record 18 of Set 10 | makakilo city
# Processing Record 19 of Set 10 | tandil
# Processing Record 20 of Set 10 | langsa
# Processing Record 21 of Set 10 | los aquijes
# Processing Record 22 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 10 | taltal
# Processing Record 24 of Set 10 | chippewa falls
# Processing Record 25 of Set 10 | thinadhoo
# Processing Record 26 of Set 10 | sambava
# Processing Record 27 of Set 10 | chulym
# Processing Record 28 of Set 10 | college
# Processing Record 29 of Set 10 | camacha
# Processing Record 30 of Set 10 | larsnes
# Processing Record 31 of Set 10 | loukhi
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | santo antonio do sudoeste
# Processing Record 34 of Set 10 | srbobran
# Processing Record 35 of Set 10 | kailua
# Processing Record 36 of Set 10 | przeworsk
# Processing Record 37 of Set 10 | jibuti
# Processing Record 38 of Set 10 | monticello
# Processing Record 39 of Set 10 | raga
# Processing Record 40 of Set 10 | aklavik
# Processing Record 41 of Set 10 | andapa
# Processing Record 42 of Set 10 | codrington
# Processing Record 43 of Set 10 | velingara
# Processing Record 44 of Set 10 | abnub
# Processing Record 45 of Set 10 | minden
# Processing Record 46 of Set 10 | kayankulam
# Processing Record 47 of Set 10 | ha giang
# Processing Record 48 of Set 10 | muros
# Processing Record 49 of Set 10 | shitanjing
# Processing Record 50 of Set 10 | tashigang
# Processing Record 1 of Set 11 | straumen
# Processing Record 2 of Set 11 | assiniboia
# Processing Record 3 of Set 11 | tual
# Processing Record 4 of Set 11 | aswan
# Processing Record 5 of Set 11 | kauhajoki
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | grand island
# Processing Record 8 of Set 11 | kopavogur
# Processing Record 9 of Set 11 | dejen
# Processing Record 10 of Set 11 | linhares
# Processing Record 11 of Set 11 | zheleznodorozhnyy
# Processing Record 12 of Set 11 | uray
# Processing Record 13 of Set 11 | ostrovnoy
# Processing Record 14 of Set 11 | zhezkazgan
# Processing Record 15 of Set 11 | matay
# Processing Record 16 of Set 11 | atherton
# Processing Record 17 of Set 11 | xam nua
# Processing Record 18 of Set 11 | beloha
# Processing Record 19 of Set 11 | prince rupert
# Processing Record 20 of Set 11 | a
# City not found. Skipping...
# Processing Record 21 of Set 11 | nuevo progreso
# Processing Record 22 of Set 11 | tura
# Processing Record 23 of Set 11 | oshakati
# Processing Record 24 of Set 11 | shetpe
# Processing Record 25 of Set 11 | oktyabrskoye
# Processing Record 26 of Set 11 | gornyak
# Processing Record 27 of Set 11 | talas
# Processing Record 28 of Set 11 | bataipora
# Processing Record 29 of Set 11 | bagdarin
# Processing Record 30 of Set 11 | ayorou
# Processing Record 31 of Set 11 | bonavista
# Processing Record 32 of Set 11 | meulaboh
# Processing Record 33 of Set 11 | aleksandrov gay
# Processing Record 34 of Set 11 | matale
# Processing Record 35 of Set 11 | buin
# Processing Record 36 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 11 | palu
# Processing Record 38 of Set 11 | zhanaozen
# Processing Record 39 of Set 11 | basti
# Processing Record 40 of Set 11 | pineville
# Processing Record 41 of Set 11 | tiarei
# Processing Record 42 of Set 11 | baghdad
# Processing Record 43 of Set 11 | kalianget
# Processing Record 44 of Set 11 | honningsvag
# Processing Record 45 of Set 11 | nador
# Processing Record 46 of Set 11 | cherskiy
# Processing Record 47 of Set 11 | goundi
# Processing Record 48 of Set 11 | middelburg
# Processing Record 49 of Set 11 | chapais
# Processing Record 50 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 12 | minudasht
# Processing Record 2 of Set 12 | tuban
# Processing Record 3 of Set 12 | palora
# Processing Record 4 of Set 12 | mbanza-ngungu
# Processing Record 5 of Set 12 | saint-francois
# Processing Record 6 of Set 12 | kamenka
# Processing Record 7 of Set 12 | assis
# Processing Record 8 of Set 12 | bardiyah
# Processing Record 9 of Set 12 | pringsewu
# Processing Record 10 of Set 12 | luwuk
# Processing Record 11 of Set 12 | jalingo
# Processing Record 12 of Set 12 | kulhudhuffushi
# Processing Record 13 of Set 12 | sug-aksy
# City not found. Skipping...
# Processing Record 14 of Set 12 | kawalu
# Processing Record 15 of Set 12 | menongue
# Processing Record 16 of Set 12 | svetlyy
# Processing Record 17 of Set 12 | sur
# Processing Record 18 of Set 12 | talnakh
# Processing Record 19 of Set 12 | mezen
# Processing Record 20 of Set 12 | cacoal
# Processing Record 21 of Set 12 | ende
# Processing Record 22 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 23 of Set 12 | itaituba
# Processing Record 24 of Set 12 | flinders
# Processing Record 25 of Set 12 | chengzihe
# Processing Record 26 of Set 12 | halifax
# Processing Record 27 of Set 12 | cockburn town
# Processing Record 28 of Set 12 | koraput
# Processing Record 29 of Set 12 | merrill
# Processing Record 30 of Set 12 | nova olinda do norte
# Processing Record 31 of Set 12 | kiama
# Processing Record 32 of Set 12 | mackenzie
# Processing Record 33 of Set 12 | rio verde de mato grosso
# Processing Record 34 of Set 12 | maua
# Processing Record 35 of Set 12 | port augusta
# Processing Record 36 of Set 12 | ambilobe
# Processing Record 37 of Set 12 | maniitsoq
# Processing Record 38 of Set 12 | zonguldak
# Processing Record 39 of Set 12 | harper
# Processing Record 40 of Set 12 | leh
# Processing Record 41 of Set 12 | tilichiki
# Processing Record 42 of Set 12 | san miguel
# Processing Record 43 of Set 12 | linapacan
# City not found. Skipping...
# Processing Record 44 of Set 12 | craig
# Processing Record 45 of Set 12 | olinda
# Processing Record 46 of Set 12 | ponoka
# Processing Record 47 of Set 12 | port keats
# Processing Record 48 of Set 12 | ngunguru
# Processing Record 49 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 12 | leonidovo
# Processing Record 1 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 13 | tigil
# Processing Record 3 of Set 13 | dunedin
# Processing Record 4 of Set 13 | imeni poliny osipenko
# Processing Record 5 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 13 | sandpoint
# Processing Record 7 of Set 13 | kisaran
# Processing Record 8 of Set 13 | hobyo
# Processing Record 9 of Set 13 | banda aceh
# Processing Record 10 of Set 13 | leona vicario
# Processing Record 11 of Set 13 | newport
# Processing Record 12 of Set 13 | mount gambier
# Processing Record 13 of Set 13 | vanavara
# Processing Record 14 of Set 13 | navolato
# Processing Record 15 of Set 13 | denpasar
# Processing Record 16 of Set 13 | berlevag
# Processing Record 17 of Set 13 | boa vista
# Processing Record 18 of Set 13 | lulea
# Processing Record 19 of Set 13 | hammerfest
# Processing Record 20 of Set 13 | alyangula
# Processing Record 21 of Set 13 | nouakchott
# Processing Record 22 of Set 13 | mattawa
# Processing Record 23 of Set 13 | bristol
# Processing Record 24 of Set 13 | mae sai
# Processing Record 25 of Set 13 | general roca
# Processing Record 26 of Set 13 | vestmannaeyjar
# Processing Record 27 of Set 13 | polyarnyy
# Processing Record 28 of Set 13 | prainha
# Processing Record 29 of Set 13 | mehamn
# Processing Record 30 of Set 13 | maues
# Processing Record 31 of Set 13 | san rafael
# Processing Record 32 of Set 13 | labuan
# Processing Record 33 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 13 | hami
# Processing Record 35 of Set 13 | pitkyaranta
# Processing Record 36 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 37 of Set 13 | iquique
# Processing Record 38 of Set 13 | the valley
# Processing Record 39 of Set 13 | maarianhamina
# Processing Record 40 of Set 13 | monrovia
# Processing Record 41 of Set 13 | sampit
# Processing Record 42 of Set 13 | pavilosta
# Processing Record 43 of Set 13 | dwarka
# Processing Record 44 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 13 | shenzhen
# Processing Record 46 of Set 13 | rwamagana
# Processing Record 47 of Set 13 | krasnyy chikoy
# Processing Record 48 of Set 13 | enzan
# Processing Record 49 of Set 13 | mount isa
# Processing Record 50 of Set 13 | kushima
# Processing Record 1 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 14 | payson
# Processing Record 3 of Set 14 | tandalti
# Processing Record 4 of Set 14 | basco
# Processing Record 5 of Set 14 | fort nelson
# Processing Record 6 of Set 14 | mabaruma
# Processing Record 7 of Set 14 | fomboni
# Processing Record 8 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 9 of Set 14 | cidreira
# Processing Record 10 of Set 14 | ladson
# Processing Record 11 of Set 14 | buluang
# Processing Record 12 of Set 14 | grand-lahou
# Processing Record 13 of Set 14 | namatanai
# Processing Record 14 of Set 14 | ullapool
# Processing Record 15 of Set 14 | hermon
# Processing Record 16 of Set 14 | paamiut
# Processing Record 17 of Set 14 | seabra
# Processing Record 18 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 14 | zwedru
# Processing Record 20 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 14 | pingliang
# Processing Record 22 of Set 14 | lebyazhye
# Processing Record 23 of Set 14 | haapsalu
# Processing Record 24 of Set 14 | thano bula khan
# City not found. Skipping...
# Processing Record 25 of Set 14 | astipalaia
# City not found. Skipping...
# Processing Record 26 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 14 | canon city
# Processing Record 28 of Set 14 | tahta
# Processing Record 29 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 30 of Set 14 | betafo
# Processing Record 31 of Set 14 | athens
# Processing Record 32 of Set 14 | taoudenni
# Processing Record 33 of Set 14 | makinsk
# Processing Record 34 of Set 14 | wanning
# Processing Record 35 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 14 | swan river
# Processing Record 37 of Set 14 | central point
# Processing Record 38 of Set 14 | aguimes
# Processing Record 39 of Set 14 | manggar
# Processing Record 40 of Set 14 | nioki
# Processing Record 41 of Set 14 | nome
# Processing Record 42 of Set 14 | coquimbo
# Processing Record 43 of Set 14 | constantine
# Processing Record 44 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 14 | alice springs
# Processing Record 46 of Set 14 | iranshahr
# Processing Record 47 of Set 14 | vestmanna
# Processing Record 48 of Set 14 | lobito
# Processing Record 49 of Set 14 | snezhnogorsk
# Processing Record 50 of Set 14 | urucara
# Processing Record 1 of Set 15 | autun
# Processing Record 2 of Set 15 | hinton
# Processing Record 3 of Set 15 | bara
# Processing Record 4 of Set 15 | miramar
# Processing Record 5 of Set 15 | wilmington
# Processing Record 6 of Set 15 | calama
# Processing Record 7 of Set 15 | calabozo
# Processing Record 8 of Set 15 | mukhen
# Processing Record 9 of Set 15 | ayer itam
# City not found. Skipping...
# Processing Record 10 of Set 15 | sharkan
# Processing Record 11 of Set 15 | sisimiut
# Processing Record 12 of Set 15 | nalut
# Processing Record 13 of Set 15 | angoche
# Processing Record 14 of Set 15 | jijiga
# Processing Record 15 of Set 15 | san vicente
# Processing Record 16 of Set 15 | zhangye
# Processing Record 17 of Set 15 | jomalig
# City not found. Skipping...
# Processing Record 18 of Set 15 | tambun
# Processing Record 19 of Set 15 | balaguer
# Processing Record 20 of Set 15 | madras
# Processing Record 21 of Set 15 | hay river
# Processing Record 22 of Set 15 | deming
# Processing Record 23 of Set 15 | bunia
# Processing Record 24 of Set 15 | biu
# Processing Record 25 of Set 15 | sao jose da coroa grande
# Processing Record 26 of Set 15 | buala
# Processing Record 27 of Set 15 | naze
# Processing Record 28 of Set 15 | uruacu
# Processing Record 29 of Set 15 | bahia blanca
# Processing Record 30 of Set 15 | tanout
# Processing Record 31 of Set 15 | westport
# Processing Record 32 of Set 15 | chik
# Processing Record 33 of Set 15 | hirado
# Processing Record 34 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 15 | ambanja
# Processing Record 36 of Set 15 | gamboma
# Processing Record 37 of Set 15 | krasnotorka
# Processing Record 38 of Set 15 | bantacan
# Processing Record 39 of Set 15 | west bend
# Processing Record 40 of Set 15 | senno
# Processing Record 41 of Set 15 | cacule
# Processing Record 42 of Set 15 | roma
# Processing Record 43 of Set 15 | fairbanks
# Processing Record 44 of Set 15 | shadegan
# Processing Record 45 of Set 15 | baykit
# Processing Record 46 of Set 15 | yuci
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 684

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Barrow      US  71.2906 -156.7887     19.54        93          30
# 1  Yellowknife      CA  62.4560 -114.3525     27.12        74          75
# 2        Airai      TL  -8.9266  125.4092     61.43        80          73
# 3    Mahebourg      MU -20.4081   57.7000     73.26        81          31
# 4      Itarema      BR  -2.9248  -39.9167     83.66        65          13
# 5  Tuktoyaktuk      CA  69.4541 -133.0374     13.10        84          21
# 6      Mataura      NZ -46.1927  168.8643     45.82        99         100
# 7   Marshfield      US  44.6689  -90.1718     72.66        56           0
# 8       Marawi      PH   7.9986  124.2928     68.81        93         100
# 9      Ushuaia      AR -54.8000  -68.3000     50.29        74          36
#
#    Wind Speed Current Description
# 0       18.21    scattered clouds
# 1        5.75       broken clouds
# 2        2.71       broken clouds
# 3       10.40    scattered clouds
# 4       16.58          few clouds
# 5        8.79          few clouds
# 6        7.92       moderate rain
# 7       14.97           clear sky
# 8        1.50     overcast clouds
# 9        5.99    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order

df = city_data_df[new_column_order]

# Display sample data

df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Barrow      US  71.2906 -156.7887     19.54        93          30
# 1  Yellowknife      CA  62.4560 -114.3525     27.12        74          75
# 2        Airai      TL  -8.9266  125.4092     61.43        80          73
# 3    Mahebourg      MU -20.4081   57.7000     73.26        81          31
# 4      Itarema      BR  -2.9248  -39.9167     83.66        65          13
# 5  Tuktoyaktuk      CA  69.4541 -133.0374     13.10        84          21
# 6      Mataura      NZ -46.1927  168.8643     45.82        99         100
# 7   Marshfield      US  44.6689  -90.1718     72.66        56           0
# 8       Marawi      PH   7.9986  124.2928     68.81        93         100
# 9      Ushuaia      AR -54.8000  -68.3000     50.29        74          36
#
#    Wind Speed Current Description
# 0       18.21    scattered clouds
# 1        5.75       broken clouds
# 2        2.71       broken clouds
# 3       10.40    scattered clouds
# 4       16.58          few clouds
# 5        8.79          few clouds
# 6        7.92       moderate rain
# 7       14.97           clear sky
# 8        1.50     overcast clouds
# 9        5.99    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
